# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json
import pandas as pd
# Out:
# C:\Users\mihae\AppData\Local\Temp\ipykernel_22456\748694261.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
with open("data/paaspop_friday.json", "r") as f:
    file_content = json.load(f)

# %%
timetable_df = pd.DataFrame(file_content)

# %%
timetable_df
# Out:
#             start            end               artist               stage
# 0   1649347200000  1649349900000                 MEAU              Apollo
# 1   1649352600000  1649356200000             Flemming              Apollo
# 2   1649359800000  1649363400000               Antoon              Apollo
# 3   1649367000000  1649370600000              DI-RECT              Apollo
# 4   1649374200000  1649466000000          Limp Bizkit              Apollo
# ..            ...            ...                  ...                 ...
# 95  1649359800000  1649361600000           Braboneger  The Little Theatre
# 96  1649361600000  1649363400000   Martijn oosterhuis  The Little Theatre
# 97  1649363400000  1649366100000  Van Binsbergen Trio  The Little Theatre
# 98  1649367900000  1649462400000                Bingo  The Little Theatre
# 99  1649289600000  1649293200000           Vincenergy  The Little Theatre
#
# [100 rows x 4 columns]

# %%
with open("restructured_timetable.json", "r") as f:
    restructured_timetable = json.load(f)

# %% [markdown]
# JSON oregano schemer
# ```
# <stage_name> : [
#     {
#         "arteest": <>,
#         "start": <>,
#         "end": <>,
#     },
#     ...
# ]
# ```
#
#
# JSON later one schemer
# ```
# <stage_name> : [
#     {
#         "arteest": <>,
#         "start": <>,
#         "end": <>,
#         "genres": [<>],
#         "popularity": <>,
#         "arteest_ider": <>,
#     },
#     ...
# ]
# ```

# %%
restructured_timetable
# Out:
# {'timetable': {'Apollo': [{'artist': 'MEAU',
#     'start': 1649347200000,
#     'end': 1649349900000},
#    {'artist': 'Flemming', 'start': 1649352600000, 'end': 1649356200000},
#    {'artist': 'Antoon', 'start': 1649359800000, 'end': 1649363400000},
#    {'artist': 'DI-RECT', 'start': 1649367000000, 'end': 1649370600000},
#    {'artist': 'Limp Bizkit', 'start': 1649374200000, 'end': 1649466000000}],
#   'Phoenix': [{'artist': 'Tabitha',
#     'start': 1649349000000,
#     'end': 1649352600000},
#    {'artist': 'Triggerfinger', 'start': 1649356200000, 'end': 1649359800000},
#    {'artist': 'Frank Carter & The Rattlesnakes',
#     'start': 1649363400000,
#     'end': 1649367000000},
#    {'artist': 'Pan-Pot', 'start': 1649368800000, 'end': 1649374200000},
#    {'artist': 'Enrico Sangiuliano',
#     'start': 1649374200000,
#     'end': 1649466000000}],
#   'Roxy': [{'artist': 'Brunzyn', 'start': 1649349900000, 'end': 1649351700000},
#    {'artist': 'Cor', 'start': 1649353500000, 'end': 1649355300000},
#    {'artist': 'Bente', 'start': 1649360700000, 'end': 1649363400000},
#    {'artist': 'Dopebwoy', 'start': 1649365200000, 'end': 1649367900000},
#    {'artist': 'Rotjoch', 'start': 1649370600000, 'end': 1649373300000},
#    {'artist': 'Go_A', 'start': 1649289600000, 'end': 1649293200000}],
#   'The sIlver Warehouse': [{'artist': 'La June',
#     'start': 1649347200000,
#     'end': 1649350800000},
#    {'artist': 'Irwan', 'start': 1649350800000, 'end': 1649354400000},
#    {'artist': 'Sam Hofman', 'start': 1649354400000, 'end': 1649358000000},
#    {'artist': 'Mr. Belt & Wezol',
#     'start': 1649358000000,
#     'end': 1649361600000},
#    {'artist': 'La Fuente', 'start': 1649361600000, 'end': 1649365200000},
#    {'artist': 'Kris Kross Amsterdam',
#     'start': 1649365200000,
#     'end': 1649368800000},
#    {'artist': 'Adaro', 'start': 1649368800000, 'end': 1649372400000},
#    {'artist': 'Vertile', 'start': 1649372400000, 'end': 1649462400000},
#    {'artist': 'Sefa', 'start': 1649289600000, 'end': 1649293200000}],
#   'The Jack': [{'artist': 'Wargasm',
#     'start': 1649347200000,
#     'end': 1649350800000},
#    {'artist': 'Ploegendienst', 'start': 1649354400000, 'end': 1649358000000},
#    {'artist': 'Bob Vylan', 'start': 1649361600000, 'end': 1649365200000}],
#   'Luxor': [{'artist': 'KUZKO', 'start': 1649349900000, 'end': 1649352600000},
#    {'artist': 'Gallus', 'start': 1649356200000, 'end': 1649359800000},
#    {'artist': 'The Blue Stones', 'start': 1649363400000, 'end': 1649367000000},
#    {'artist': 'Wodan Boys', 'start': 1649370600000, 'end': 1649374200000}],
#   'Theatre': [{'artist': 'Crazy Little Things',
#     'start': 1649354400000,
#     'end': 1649358900000},
#    {'artist': 'The Ultimate Michael Jackson Experience',
#     'start': 1649360700000,
#     'end': 1649365200000},
#    {'artist': 'Martijn Fischer', 'start': 1649367000000, 'end': 1649372400000},
#    {'artist': 'Baby Blue', 'start': 1649374200000, 'end': 1649466000000}],
#   'Loco Royale': [{'artist': 'Harry und Stephan',
#     'start': 1649347200000,
#     'end': 1649350800000},
#    {'artist': 'Hey Boyband, Hey Girlband',
#     'start': 1649350800000,
#     'end': 1649355300000},
#    {'artist': 'Show', 'start': 1649355300000, 'end': 1649358900000},
#    {'artist': 'Flipperdisco', 'start': 1649358900000, 'end': 1649360700000},
#    {'artist': 'Pure Ellende', 'start': 1649360700000, 'end': 1649364300000},
#    {'artist': 'Flipperdisco', 'start': 1649364300000, 'end': 1649366100000},
#    {'artist': 'STUK', 'start': 1649366100000, 'end': 1649369700000},
#    {'artist': 'Flipperdisco', 'start': 1649369700000, 'end': 1649371500000},
#    {'artist': 'Gestapo Knallmuzik',
#     'start': 1649371500000,
#     'end': 1649462400000},
#    {'artist': 'Loco Loco Discoshow',
#     'start': 1649289600000,
#     'end': 1649293200000}],
#   'Area 9': [{'artist': 'The Juke Joints',
#     'start': 1649356200000,
#     'end': 1649359800000},
#    {'artist': "We're the Men", 'start': 1649365200000, 'end': 1649368800000},
#    {'artist': 'Piledriver', 'start': 1649374200000, 'end': 1649464200000}],
#   'The Garage': [{'artist': 'The Groove Supplier',
#     'start': 1649347200000,
#     'end': 1649354400000},
#    {'artist': 'CAJA', 'start': 1649354400000, 'end': 1649358000000},
#    {'artist': 'Ome Kev', 'start': 1649358000000, 'end': 1649361600000},
#    {'artist': 'Yoshua Jr.', 'start': 1649361600000, 'end': 1649367000000},
#    {'artist': 'Groove Safari', 'start': 1649367000000, 'end': 1649372400000},
#    {'artist': 'Nothing but Funk',
#     'start': 1649372400000,
#     'end': 1649466000000}],
#   'Dolle Mina': [{'artist': 'Dirk Drost',
#     'start': 1649350800000,
#     'end': 1649352600000},
#    {'artist': 'René Ulehake', 'start': 1649356200000, 'end': 1649358000000},
#    {'artist': 'Marco Kanters', 'start': 1649363400000, 'end': 1649365200000},
#    {'artist': 'John de Bever', 'start': 1649369700000, 'end': 1649371500000},
#    {'artist': 'Arjon Oostrom', 'start': 1649289600000, 'end': 1649291400000}],
#   'The Social club': [{'artist': 'Callkoen',
#     'start': 1649347200000,
#     'end': 1649349900000},
#    {'artist': 'Papaformigas', 'start': 1649352600000, 'end': 1649356200000},
#    {'artist': 'Goeiemiddag', 'start': 1649359800000, 'end': 1649363400000},
#    {'artist': 'Doctor Krapula', 'start': 1649367000000, 'end': 1649370600000},
#    {'artist': 'The Wetnecks', 'start': 1649375100000, 'end': 1649466000000}],
#   'SMÈRRIG': [{'artist': 'SMÈRRIG Diskjochies',
#     'start': 1649343600000,
#     'end': 1649347200000},
#    {'artist': 'SiRens', 'start': 1649347200000, 'end': 1649350800000},
#    {'artist': 'Gijs Padding', 'start': 1649350800000, 'end': 1649354400000},
#    {'artist': 'Bartje Bricks', 'start': 1649354400000, 'end': 1649358000000},
#    {'artist': "Spinn'Em", 'start': 1649358000000, 'end': 1649361600000},
#    {'artist': 'Kruzo', 'start': 1649361600000, 'end': 1649365200000},
#    {'artist': "Be Charm'D", 'start': 1649365200000, 'end': 1649368800000},
#    {'artist': 'Golddiggers', 'start': 1649368800000, 'end': 1649372400000},
#    {'artist': 'Rugged', 'start': 1649372400000, 'end': 1649462400000},
#    {'artist': 'Moschino', 'start': 1649289600000, 'end': 1649293200000}],
#   'Disco Snolly': [{'artist': 'Robbie Lion',
#     'start': 1649343600000,
#     'end': 1649349000000},
#    {'artist': 'De Manager', 'start': 1649349000000, 'end': 1649354400000},
#    {'artist': 'Tommy Summer', 'start': 1649354400000, 'end': 1649359800000},
#    {'artist': 'Disco Derek', 'start': 1649359800000, 'end': 1649365200000},
#    {'artist': 'FissABBAnd', 'start': 1649365200000, 'end': 1649368800000},
#    {'artist': 'Keezus Christus', 'start': 1649368800000, 'end': 1649374200000},
#    {'artist': 'Disco Snolly', 'start': 1649374200000, 'end': 1649466000000}],
#   'Casa Barcardi': [{'artist': 'K-man',
#     'start': 1649343600000,
#     'end': 1649349000000},
#    {'artist': 'Morry', 'start': 1649349000000, 'end': 1649355300000},
#    {'artist': 'Nereo', 'start': 1649355300000, 'end': 1649356200000},
#    {'artist': 'Elin Valery', 'start': 1649358000000, 'end': 1649362500000},
#    {'artist': 'Jorda', 'start': 1649362500000, 'end': 1649365800000},
#    {'artist': 'Kilate Tesla', 'start': 1649365800000, 'end': 1649367000000},
#    {'artist': 'Morry', 'start': 1649367000000, 'end': 1649372400000},
#    {'artist': 'MIMI', 'start': 1649372400000, 'end': 1649462400000},
#    {'artist': 'Jorda', 'start': 1649289600000, 'end': 1649293200000}],
#   'The Little Theatre': [{'artist': 'Van Binsbergen Trio',
#     'start': 1649350800000,
#     'end': 1649353500000},
#    {'artist': 'Braboneger', 'start': 1649353500000, 'end': 1649355300000},
#    {'artist': 'Martijn oosterhuis',
#     'start': 1649355300000,
#     'end': 1649357100000},
#    {'artist': 'Van Binsbergen Trio',
#     'start': 1649357100000,
#     'end': 1649359800000},
#    {'artist': 'Braboneger', 'start': 1649359800000, 'end': 1649361600000},
#    {'artist': 'Martijn oosterhuis',
#     'start': 1649361600000,
#     'end': 1649363400000},
#    {'artist': 'Van Binsbergen Trio',
#     'start': 1649363400000,
#     'end': 1649366100000},
#    {'artist': 'Bingo', 'start': 1649367900000, 'end': 1649462400000},
#    {'artist': 'Vincenergy', 'start': 1649289600000, 'end': 1649293200000}]}}

# %%
with open("spotify_dict.json", "r") as f:
    spotify_dict = json.load(f)

# %%
dfs = []
for stage, data in restructured_timetable["timetable"].items():
    df = pd.DataFrame(data)
    df["stage"] = stage
    dfs.append(df)
timetable_df = pd.concat(dfs)

# %%
spotify_df = pd.DataFrame(spotify_dict)

# %%
spotify_df = spotify_df.rename(columns={"name":"artist"})

# %%
spotify_df
# Out:
#                   artist               artist_id  \
# 0            Limp Bizkit  165ZgPlLkK7bf5bDoFc6Sb
# 1   Kris Kross Amsterdam  4LcUpNlXFEleaLlelmkv2R
# 2               Dopebwoy  6OQggpm01CmAB717TKtDCr
# 3                 Antoon  5sBoNBXFMzoZjgHLbQueeG
# 4                   Sefa  0caJEGgVuXuSHhhrMCmlkI
# ..                   ...                     ...
# 59               Ome Kev  1esYIpXQ7gz698ru1nMZrD
# 60            Dirk Drost  3nK6TYPkGYtOVooSX52j7A
# 61            Braboneger  0eK5mdmnyNtFLFQpeIcNqt
# 62              Moschino  35izkOT62LTsw9eNF2UFbU
# 63            De Manager  6VTHagpigZbq1jEgAXtlmE
#
#                                                genres  popularity
# 0   [alternative metal, funk metal, nu metal, post...          74
# 1                            [dutch house, dutch pop]          62
# 2                      [dutch hip hop, dutch rap pop]          58
# 3                                           [lustrum]          58
# 4                [frenchcore, tekk, uptempo hardcore]          57
# ..                                                ...         ...
# 59                                                 []           0
# 60                                                 []           0
# 61                                                 []           0
# 62                                                 []           0
# 63                                                 []           0
#
# [64 rows x 4 columns]

# %%
timetable_df
# Out:
#             start            end               artist               stage
# 0   1649347200000  1649349900000                 MEAU              Apollo
# 1   1649352600000  1649356200000             Flemming              Apollo
# 2   1649359800000  1649363400000               Antoon              Apollo
# 3   1649367000000  1649370600000              DI-RECT              Apollo
# 4   1649374200000  1649466000000          Limp Bizkit              Apollo
# ..            ...            ...                  ...                 ...
# 95  1649359800000  1649361600000           Braboneger  The Little Theatre
# 96  1649361600000  1649363400000   Martijn oosterhuis  The Little Theatre
# 97  1649363400000  1649366100000  Van Binsbergen Trio  The Little Theatre
# 98  1649367900000  1649462400000                Bingo  The Little Theatre
# 99  1649289600000  1649293200000           Vincenergy  The Little Theatre
#
# [100 rows x 4 columns]

# %%
df = spotify_df.merge(timetable_df, on="artist")

# %%
df = df.sort_values(by=["start", "end"])
groups = df.groupby("stage")
output_dict = {}
for stage, dater in groups:
    output_dict[stage] = list(dater.to_dict("index").values())

# %%
output_dict
# Out:
# {'Apollo': [{'artist': 'MEAU',
#    'artist_id': '2F3Mdh2idBVOiMTxXoxc10',
#    'genres': ['dutch pop'],
#    'popularity': 55,
#    'start': 1649347200000,
#    'end': 1649349900000,
#    'stage': 'Apollo'},
#   {'artist': 'Flemming',
#    'artist_id': '2M8xumdC8KOtdVgjumHYR7',
#    'genres': [],
#    'popularity': 3,
#    'start': 1649352600000,
#    'end': 1649356200000,
#    'stage': 'Apollo'},
#   {'artist': 'Antoon',
#    'artist_id': '5sBoNBXFMzoZjgHLbQueeG',
#    'genres': ['lustrum'],
#    'popularity': 58,
#    'start': 1649359800000,
#    'end': 1649363400000,
#    'stage': 'Apollo'},
#   {'artist': 'DI-RECT',
#    'artist_id': '0d1nFNO90pwRmCeeqjOx2Q',
#    'genres': ['dutch pop', 'dutch rock'],
#    'popularity': 52,
#    'start': 1649367000000,
#    'end': 1649370600000,
#    'stage': 'Apollo'},
#   {'artist': 'Limp Bizkit',
#    'artist_id': '165ZgPlLkK7bf5bDoFc6Sb',
#    'genres': ['alternative metal',
#     'funk metal',
#     'nu metal',
#     'post-grunge',
#     'rap metal',
#     'rock'],
#    'popularity': 74,
#    'start': 1649374200000,
#    'end': 1649466000000,
#    'stage': 'Apollo'}],
#  'Area 9': [{'artist': 'The Juke Joints',
#    'artist_id': '3B8uylp9cvNkcg8XOSZ3c9',
#    'genres': ['dutch blues'],
#    'popularity': 8,
#    'start': 1649356200000,
#    'end': 1649359800000,
#    'stage': 'Area 9'},
#   {'artist': 'Piledriver',
#    'artist_id': '4IkzquGzaHJr0O4snJAoSb',
#    'genres': ['old school thrash'],
#    'popularity': 11,
#    'start': 1649374200000,
#    'end': 1649464200000,
#    'stage': 'Area 9'}],
#  'Casa Barcardi': [{'artist': 'Jorda',
#    'artist_id': '2JFrOlm8n2quN9uQ2lkeO5',
#    'genres': [],
#    'popularity': 28,
#    'start': 1649289600000,
#    'end': 1649293200000,
#    'stage': 'Casa Barcardi'},
#   {'artist': 'Morry',
#    'artist_id': '1CXa8YMTen75u0n1rvtk0u',
#    'genres': [],
#    'popularity': 27,
#    'start': 1649349000000,
#    'end': 1649355300000,
#    'stage': 'Casa Barcardi'},
#   {'artist': 'Nereo',
#    'artist_id': '5bO4qIfLbIYaI685z1tGoi',
#    'genres': [],
#    'popularity': 0,
#    'start': 1649355300000,
#    'end': 1649356200000,
#    'stage': 'Casa Barcardi'},
#   {'artist': 'Elin Valery',
#    'artist_id': '45z8eLb85OUwgx6LNZZaAK',
#    'genres': [],
#    'popularity': 0,
#    'start': 1649358000000,
#    'end': 1649362500000,
#    'stage': 'Casa Barcardi'},
#   {'artist': 'Jorda',
#    'artist_id': '2JFrOlm8n2quN9uQ2lkeO5',
#    'genres': [],
#    'popularity': 28,
#    'start': 1649362500000,
#    'end': 1649365800000,
#    'stage': 'Casa Barcardi'},
#   {'artist': 'Morry',
#    'artist_id': '1CXa8YMTen75u0n1rvtk0u',
#    'genres': [],
#    'popularity': 27,
#    'start': 1649367000000,
#    'end': 1649372400000,
#    'stage': 'Casa Barcardi'},
#   {'artist': 'MIMI',
#    'artist_id': '0nwGsQzwVqdlBAg0eSNxmd',
#    'genres': ['vocaloid'],
#    'popularity': 49,
#    'start': 1649372400000,
#    'end': 1649462400000,
#    'stage': 'Casa Barcardi'}],
#  'Disco Snolly': [{'artist': 'De Manager',
#    'artist_id': '6VTHagpigZbq1jEgAXtlmE',
#    'genres': [],
#    'popularity': 0,
#    'start': 1649349000000,
#    'end': 1649354400000,
#    'stage': 'Disco Snolly'},
#   {'artist': 'Disco Snolly',
#    'artist_id': '2E5q3OwDr5WR0Bfcwpunhb',
#    'genres': [],
#    'popularity': 16,
#    'start': 1649374200000,
#    'end': 1649466000000,
#    'stage': 'Disco Snolly'}],
#  'Dolle Mina': [{'artist': 'Arjon Oostrom',
#    'artist_id': '2sdP2pb74y3kf44RxZwaCb',
#    'genres': ['carnaval', 'levenslied'],
#    'popularity': 41,
#    'start': 1649289600000,
#    'end': 1649291400000,
#    'stage': 'Dolle Mina'},
#   {'artist': 'Dirk Drost',
#    'artist_id': '3nK6TYPkGYtOVooSX52j7A',
#    'genres': [],
#    'popularity': 0,
#    'start': 1649350800000,
#    'end': 1649352600000,
#    'stage': 'Dolle Mina'},
#   {'artist': 'René Ulehake',
#    'artist_id': '0PCA8sf9m99GF1nxZYq2me',
#    'genres': [],
#    'popularity': 0,
#    'start': 1649356200000,
#    'end': 1649358000000,
#    'stage': 'Dolle Mina'},
#   {'artist': 'Marco Kanters',
#    'artist_id': '2VF4qPKEmzjjssI2razMNt',
#    'genres': ['carnaval', 'levenslied'],
#    'popularity': 36,
#    'start': 1649363400000,
#    'end': 1649365200000,
#    'stage': 'Dolle Mina'}],
#  'Loco Royale': [{'artist': 'Show',
#    'artist_id': '2lXKd25ihVzaQf7rDaijUh',
#    'genres': [],
#    'popularity': 5,
#    'start': 1649355300000,
#    'end': 1649358900000,
#    'stage': 'Loco Royale'},
#   {'artist': 'Pure Ellende',
#    'artist_id': '63czbS5lyZfjE3M8b0bPdX',
#    'genres': [],
#    'popularity': 0,
#    'start': 1649360700000,
#    'end': 1649364300000,
#    'stage': 'Loco Royale'},
#   {'artist': 'STUK',
#    'artist_id': '0MnM8NE69iw1cVc7GVIZ41',
#    'genres': ['nederlandse hardstyle'],
#    'popularity': 36,
#    'start': 1649366100000,
#    'end': 1649369700000,
#    'stage': 'Loco Royale'},
#   {'artist': 'Gestapo Knallmuzik',
#    'artist_id': '1nqxhx0g04Qzeq2rr46sCk',
#    'genres': ['vlaamse cabaret'],
#    'popularity': 18,
#    'start': 1649371500000,
#    'end': 1649462400000,
#    'stage': 'Loco Royale'}],
#  'Luxor': [{'artist': 'KUZKO',
#    'artist_id': '1XwtSHxSZ06XfQ0qah9Rxo',
#    'genres': ['rotterdam indie'],
#    'popularity': 13,
#    'start': 1649349900000,
#    'end': 1649352600000,
#    'stage': 'Luxor'},
#   {'artist': 'Gallus',
#    'artist_id': '3DTAfcWpBw0deOabOAtNVC',
#    'genres': ['glasgow indie', 'scottish indie rock'],
#    'popularity': 18,
#    'start': 1649356200000,
#    'end': 1649359800000,
#    'stage': 'Luxor'},
#   {'artist': 'The Blue Stones',
#    'artist_id': '5VPCIIfZPK8KPsgz4jmOEC',
#    'genres': ['modern alternative rock',
#     'modern blues rock',
#     'modern hard rock',
#     'windsor on indie'],
#    'popularity': 52,
#    'start': 1649363400000,
#    'end': 1649367000000,
#    'stage': 'Luxor'},
#   {'artist': 'Wodan Boys',
#    'artist_id': '0kmKbibEVmQ4luQqUAHDMr',
#    'genres': ['dutch rock'],
#    'popularity': 17,
#    'start': 1649370600000,
#    'end': 1649374200000,
#    'stage': 'Luxor'}],
#  'Phoenix': [{'artist': 'Tabitha',
#    'artist_id': '7iBY1RLWDV5zX9NDNQxurm',
#    'genres': ['dutch pop', 'dutch rap pop'],
#    'popularity': 56,
#    'start': 1649349000000,
#    'end': 1649352600000,
#    'stage': 'Phoenix'},
#   {'artist': 'Triggerfinger',
#    'artist_id': '3UhIlk54Oe4ja06V962ptU',
#    'genres': ['belgian rock'],
#    'popularity': 39,
#    'start': 1649356200000,
#    'end': 1649359800000,
#    'stage': 'Phoenix'},
#   {'artist': 'Frank Carter & The Rattlesnakes',
#    'artist_id': '3r32a6mMdoPaSP1C7kYhMc',
#    'genres': ['british alternative rock', 'modern alternative rock'],
#    'popularity': 47,
#    'start': 1649363400000,
#    'end': 1649367000000,
#    'stage': 'Phoenix'},
#   {'artist': 'Pan-Pot',
#    'artist_id': '6OQOvP7RAdmAKVXXQqD0Se',
#    'genres': ['german techno', 'minimal techno', 'raw techno'],
#    'popularity': 39,
#    'start': 1649368800000,
#    'end': 1649374200000,
#    'stage': 'Phoenix'},
#   {'artist': 'Enrico Sangiuliano',
#    'artist_id': '1u7DsNFbakULvxnDGtMm90',
#    'genres': ['dark techno', 'italian techno'],
#    'popularity': 55,
#    'start': 1649374200000,
#    'end': 1649466000000,
#    'stage': 'Phoenix'}],
#  'Roxy': [{'artist': 'Go_A',
#    'artist_id': '4kvCU3MzggM2piZCqvxj0x',
#    'genres': ['ukrainian viral pop'],
#    'popularity': 48,
#    'start': 1649289600000,
#    'end': 1649293200000,
#    'stage': 'Roxy'},
#   {'artist': 'Brunzyn',
#    'artist_id': '34zjBncq7MEAoNwsM1DMU9',
#    'genres': [],
#    'popularity': 35,
#    'start': 1649349900000,
#    'end': 1649351700000,
#    'stage': 'Roxy'},
#   {'artist': 'Cor',
#    'artist_id': '66wqVYADY665LeMxs8nlk3',
#    'genres': ['dutch hip hop'],
#    'popularity': 47,
#    'start': 1649353500000,
#    'end': 1649355300000,
#    'stage': 'Roxy'},
#   {'artist': 'Bente',
#    'artist_id': '4U9nsRTH2mr9L4UXEWqG5e',
#    'genres': ['dutch pop'],
#    'popularity': 42,
#    'start': 1649360700000,
#    'end': 1649363400000,
#    'stage': 'Roxy'},
#   {'artist': 'Dopebwoy',
#    'artist_id': '6OQggpm01CmAB717TKtDCr',
#    'genres': ['dutch hip hop', 'dutch rap pop'],
#    'popularity': 58,
#    'start': 1649365200000,
#    'end': 1649367900000,
#    'stage': 'Roxy'},
#   {'artist': 'Rotjoch',
#    'artist_id': '52kkq3LdnSafdKRWjNqKBw',
#    'genres': ['dutch hip hop', 'dutch rap pop'],
#    'popularity': 40,
#    'start': 1649370600000,
#    'end': 1649373300000,
#    'stage': 'Roxy'}],
#  'SMÈRRIG': [{'artist': 'Moschino',
#    'artist_id': '35izkOT62LTsw9eNF2UFbU',
#    'genres': [],
#    'popularity': 0,
#    'start': 1649289600000,
#    'end': 1649293200000,
#    'stage': 'SMÈRRIG'},
#   {'artist': 'Kruzo',
#    'artist_id': '0anbJdkjXYmreS2hXmisVG',
#    'genres': [],
#    'popularity': 31,
#    'start': 1649361600000,
#    'end': 1649365200000,
#    'stage': 'SMÈRRIG'},
#   {'artist': "Be Charm'D",
#    'artist_id': '3CW84Jm2B965uDAskggKF2',
#    'genres': [],
#    'popularity': 1,
#    'start': 1649365200000,
#    'end': 1649368800000,
#    'stage': 'SMÈRRIG'},
#   {'artist': 'Golddiggers',
#    'artist_id': '5XOZGfeMFqgizyqfaUt4t1',
#    'genres': [],
#    'popularity': 20,
#    'start': 1649368800000,
#    'end': 1649372400000,
#    'stage': 'SMÈRRIG'},
#   {'artist': 'Rugged',
#    'artist_id': '3RdyI4MkYrf0VE4suJyMDv',
#    'genres': [],
#    'popularity': 1,
#    'start': 1649372400000,
#    'end': 1649462400000,
#    'stage': 'SMÈRRIG'}],
#  'The Garage': [{'artist': 'The Groove Supplier',
#    'artist_id': '2DFdxWIx41TkkNuFIjhVbE',
#    'genres': [],
#    'popularity': 15,
#    'start': 1649347200000,
#    'end': 1649354400000,
#    'stage': 'The Garage'},
#   {'artist': 'CAJA',
#    'artist_id': '5ay5Vawcw37jUqERz1AyAr',
#    'genres': [],
#    'popularity': 5,
#    'start': 1649354400000,
#    'end': 1649358000000,
#    'stage': 'The Garage'},
#   {'artist': 'Ome Kev',
#    'artist_id': '1esYIpXQ7gz698ru1nMZrD',
#    'genres': [],
#    'popularity': 0,
#    'start': 1649358000000,
#    'end': 1649361600000,
#    'stage': 'The Garage'},
#   {'artist': 'Groove Safari',
#    'artist_id': '1jnLp3FtI86FT8ND2vnncD',
#    'genres': [],
#    'popularity': 1,
#    'start': 1649367000000,
#    'end': 1649372400000,
#    'stage': 'The Garage'}],
#  'The Jack': [{'artist': 'Wargasm',
#    'artist_id': '4heY3O8p8CQHH81wINvExe',
#    'genres': ['boston metal', 'new england metal', 'old school thrash'],
#    'popularity': 8,
#    'start': 1649347200000,
#    'end': 1649350800000,
#    'stage': 'The Jack'},
#   {'artist': 'Ploegendienst',
#    'artist_id': '2aJUvAtem0t0zRKxJsRoea',
#    'genres': ['dutch indie rock', 'dutch punk'],
#    'popularity': 24,
#    'start': 1649354400000,
#    'end': 1649358000000,
#    'stage': 'The Jack'},
#   {'artist': 'Bob Vylan',
#    'artist_id': '6XgIk9Y6qy6JCMZVime6DQ',
#    'genres': ['black punk', 'crank wave'],
#    'popularity': 42,
#    'start': 1649361600000,
#    'end': 1649365200000,
#    'stage': 'The Jack'}],
#  'The Little Theatre': [{'artist': 'Braboneger',
#    'artist_id': '0eK5mdmnyNtFLFQpeIcNqt',
#    'genres': [],
#    'popularity': 0,
#    'start': 1649353500000,
#    'end': 1649355300000,
#    'stage': 'The Little Theatre'},
#   {'artist': 'Braboneger',
#    'artist_id': '0eK5mdmnyNtFLFQpeIcNqt',
#    'genres': [],
#    'popularity': 0,
#    'start': 1649359800000,
#    'end': 1649361600000,
#    'stage': 'The Little Theatre'},
#   {'artist': 'Bingo',
#    'artist_id': '2ESUPsTVS3ffYKFCSIg9FG',
#    'genres': [],
#    'popularity': 7,
#    'start': 1649367900000,
#    'end': 1649462400000,
#    'stage': 'The Little Theatre'}],
#  'The Social club': [{'artist': 'Callkoen',
#    'artist_id': '2SZG72psx2dn8aDVJthfqs',
#    'genres': [],
#    'popularity': 2,
#    'start': 1649347200000,
#    'end': 1649349900000,
#    'stage': 'The Social club'},
#   {'artist': 'Papaformigas',
#    'artist_id': '5OFwcFh2YpR74aHjqY1NuZ',
#    'genres': [],
#    'popularity': 1,
#    'start': 1649352600000,
#    'end': 1649356200000,
#    'stage': 'The Social club'},
#   {'artist': 'The Wetnecks',
#    'artist_id': '0cyyFMYGp2G9TcVbuXYRDu',
#    'genres': [],
#    'popularity': 3,
#    'start': 1649375100000,
#    'end': 1649466000000,
#    'stage': 'The Social club'}],
#  'The sIlver Warehouse': [{'artist': 'Sefa',
#    'artist_id': '0caJEGgVuXuSHhhrMCmlkI',
#    'genres': ['frenchcore', 'tekk', 'uptempo hardcore'],
#    'popularity': 57,
#    'start': 1649289600000,
#    'end': 1649293200000,
#    'stage': 'The sIlver Warehouse'},
#   {'artist': 'La June',
#    'artist_id': '3hHBl5FjVlul5vOJ8cj72f',
#    'genres': [],
#    'popularity': 25,
#    'start': 1649347200000,
#    'end': 1649350800000,
#    'stage': 'The sIlver Warehouse'},
#   {'artist': 'Irwan',
#    'artist_id': '4UP8dCKmHZjqM4DdCqQ5H7',
#    'genres': [],
#    'popularity': 3,
#    'start': 1649350800000,
#    'end': 1649354400000,
#    'stage': 'The sIlver Warehouse'},
#   {'artist': 'Mr. Belt & Wezol',
#    'artist_id': '19VDJ9IKyBSUMDJxLsasP6',
#    'genres': ['dutch edm', 'house'],
#    'popularity': 48,
#    'start': 1649358000000,
#    'end': 1649361600000,
#    'stage': 'The sIlver Warehouse'},
#   {'artist': 'La Fuente',
#    'artist_id': '0vhJymgsCubfAfFjEGVsoD',
#    'genres': ['dutch edm', 'dutch house'],
#    'popularity': 45,
#    'start': 1649361600000,
#    'end': 1649365200000,
#    'stage': 'The sIlver Warehouse'},
#   {'artist': 'Kris Kross Amsterdam',
#    'artist_id': '4LcUpNlXFEleaLlelmkv2R',
#    'genres': ['dutch house', 'dutch pop'],
#    'popularity': 62,
#    'start': 1649365200000,
#    'end': 1649368800000,
#    'stage': 'The sIlver Warehouse'},
#   {'artist': 'Adaro',
#    'artist_id': '05ndiewdJogtosuRWN8iwF',
#    'genres': ['classic hardstyle', 'euphoric hardstyle', 'rawstyle'],
#    'popularity': 46,
#    'start': 1649368800000,
#    'end': 1649372400000,
#    'stage': 'The sIlver Warehouse'},
#   {'artist': 'Vertile',
#    'artist_id': '2CREMC4YATn7Bx9ZQku6IH',
#    'genres': ['rawstyle'],
#    'popularity': 53,
#    'start': 1649372400000,
#    'end': 1649462400000,
#    'stage': 'The sIlver Warehouse'}],
#  'Theatre': [{'artist': 'Martijn Fischer',
#    'artist_id': '3XcxxF0DcHXaSKutfg7vng',
#    'genres': [],
#    'popularity': 10,
#    'start': 1649367000000,
#    'end': 1649372400000,
#    'stage': 'Theatre'},
#   {'artist': 'Baby Blue',
#    'artist_id': '1zG1DuedWyFm98fa1iSoJX',
#    'genres': [],
#    'popularity': 31,
#    'start': 1649374200000,
#    'end': 1649466000000,
#    'stage': 'Theatre'}]}

# %%
with open("restructured_timetable_paaspop_friday.json", "r") as f:
    timetable_dict = json.load(f)

# %%
dfs = []
for stage, data in timetable_dict.items():
    timetable_df = pd.DataFrame(data)
    timetable_df["stage"] = stage
    dfs.append(timetable_df)
timetable_df = pd.concat(dfs)

# %%
stage_groups = timetable_df.groupby("stage")

# %%
recommender_outie = {}
for staageeh, dater in stage_groups:
    fermerter_dater = list(dater.to_dict('index').values())
    recommender_outie[staageeh] = fermerter_dater

# %%
recommender_outie
# Out:
# {'Apollo': [{'artist': 'MEAU',
#    'artist_id': '2F3Mdh2idBVOiMTxXoxc10',
#    'genres': ['dutch pop'],
#    'popularity': 55,
#    'start': 1649347200000,
#    'end': 1649349900000,
#    'stage': 'Apollo'},
#   {'artist': 'Flemming',
#    'artist_id': '2M8xumdC8KOtdVgjumHYR7',
#    'genres': [],
#    'popularity': 3,
#    'start': 1649352600000,
#    'end': 1649356200000,
#    'stage': 'Apollo'},
#   {'artist': 'Antoon',
#    'artist_id': '5sBoNBXFMzoZjgHLbQueeG',
#    'genres': ['lustrum'],
#    'popularity': 58,
#    'start': 1649359800000,
#    'end': 1649363400000,
#    'stage': 'Apollo'},
#   {'artist': 'DI-RECT',
#    'artist_id': '0d1nFNO90pwRmCeeqjOx2Q',
#    'genres': ['dutch pop', 'dutch rock'],
#    'popularity': 52,
#    'start': 1649367000000,
#    'end': 1649370600000,
#    'stage': 'Apollo'},
#   {'artist': 'Limp Bizkit',
#    'artist_id': '165ZgPlLkK7bf5bDoFc6Sb',
#    'genres': ['alternative metal',
#     'funk metal',
#     'nu metal',
#     'post-grunge',
#     'rap metal',
#     'rock'],
#    'popularity': 74,
#    'start': 1649374200000,
#    'end': 1649466000000,
#    'stage': 'Apollo'}],
#  'Area 9': [{'artist': 'The Juke Joints',
#    'artist_id': '3B8uylp9cvNkcg8XOSZ3c9',
#    'genres': ['dutch blues'],
#    'popularity': 8,
#    'start': 1649356200000,
#    'end': 1649359800000,
#    'stage': 'Area 9'},
#   {'artist': 'Piledriver',
#    'artist_id': '4IkzquGzaHJr0O4snJAoSb',
#    'genres': ['old school thrash'],
#    'popularity': 11,
#    'start': 1649374200000,
#    'end': 1649464200000,
#    'stage': 'Area 9'}],
#  'Casa Barcardi': [{'artist': 'Jorda',
#    'artist_id': '2JFrOlm8n2quN9uQ2lkeO5',
#    'genres': [],
#    'popularity': 28,
#    'start': 1649289600000,
#    'end': 1649293200000,
#    'stage': 'Casa Barcardi'},
#   {'artist': 'Morry',
#    'artist_id': '1CXa8YMTen75u0n1rvtk0u',
#    'genres': [],
#    'popularity': 27,
#    'start': 1649349000000,
#    'end': 1649355300000,
#    'stage': 'Casa Barcardi'},
#   {'artist': 'Nereo',
#    'artist_id': '5bO4qIfLbIYaI685z1tGoi',
#    'genres': [],
#    'popularity': 0,
#    'start': 1649355300000,
#    'end': 1649356200000,
#    'stage': 'Casa Barcardi'},
#   {'artist': 'Elin Valery',
#    'artist_id': '45z8eLb85OUwgx6LNZZaAK',
#    'genres': [],
#    'popularity': 0,
#    'start': 1649358000000,
#    'end': 1649362500000,
#    'stage': 'Casa Barcardi'},
#   {'artist': 'Jorda',
#    'artist_id': '2JFrOlm8n2quN9uQ2lkeO5',
#    'genres': [],
#    'popularity': 28,
#    'start': 1649362500000,
#    'end': 1649365800000,
#    'stage': 'Casa Barcardi'},
#   {'artist': 'Morry',
#    'artist_id': '1CXa8YMTen75u0n1rvtk0u',
#    'genres': [],
#    'popularity': 27,
#    'start': 1649367000000,
#    'end': 1649372400000,
#    'stage': 'Casa Barcardi'},
#   {'artist': 'MIMI',
#    'artist_id': '0nwGsQzwVqdlBAg0eSNxmd',
#    'genres': ['vocaloid'],
#    'popularity': 49,
#    'start': 1649372400000,
#    'end': 1649462400000,
#    'stage': 'Casa Barcardi'}],
#  'Disco Snolly': [{'artist': 'De Manager',
#    'artist_id': '6VTHagpigZbq1jEgAXtlmE',
#    'genres': [],
#    'popularity': 0,
#    'start': 1649349000000,
#    'end': 1649354400000,
#    'stage': 'Disco Snolly'},
#   {'artist': 'Disco Snolly',
#    'artist_id': '2E5q3OwDr5WR0Bfcwpunhb',
#    'genres': [],
#    'popularity': 16,
#    'start': 1649374200000,
#    'end': 1649466000000,
#    'stage': 'Disco Snolly'}],
#  'Dolle Mina': [{'artist': 'Arjon Oostrom',
#    'artist_id': '2sdP2pb74y3kf44RxZwaCb',
#    'genres': ['carnaval', 'levenslied'],
#    'popularity': 41,
#    'start': 1649289600000,
#    'end': 1649291400000,
#    'stage': 'Dolle Mina'},
#   {'artist': 'Dirk Drost',
#    'artist_id': '3nK6TYPkGYtOVooSX52j7A',
#    'genres': [],
#    'popularity': 0,
#    'start': 1649350800000,
#    'end': 1649352600000,
#    'stage': 'Dolle Mina'},
#   {'artist': 'René Ulehake',
#    'artist_id': '0PCA8sf9m99GF1nxZYq2me',
#    'genres': [],
#    'popularity': 0,
#    'start': 1649356200000,
#    'end': 1649358000000,
#    'stage': 'Dolle Mina'},
#   {'artist': 'Marco Kanters',
#    'artist_id': '2VF4qPKEmzjjssI2razMNt',
#    'genres': ['carnaval', 'levenslied'],
#    'popularity': 36,
#    'start': 1649363400000,
#    'end': 1649365200000,
#    'stage': 'Dolle Mina'}],
#  'Loco Royale': [{'artist': 'Show',
#    'artist_id': '2lXKd25ihVzaQf7rDaijUh',
#    'genres': [],
#    'popularity': 5,
#    'start': 1649355300000,
#    'end': 1649358900000,
#    'stage': 'Loco Royale'},
#   {'artist': 'Pure Ellende',
#    'artist_id': '63czbS5lyZfjE3M8b0bPdX',
#    'genres': [],
#    'popularity': 0,
#    'start': 1649360700000,
#    'end': 1649364300000,
#    'stage': 'Loco Royale'},
#   {'artist': 'STUK',
#    'artist_id': '0MnM8NE69iw1cVc7GVIZ41',
#    'genres': ['nederlandse hardstyle'],
#    'popularity': 36,
#    'start': 1649366100000,
#    'end': 1649369700000,
#    'stage': 'Loco Royale'},
#   {'artist': 'Gestapo Knallmuzik',
#    'artist_id': '1nqxhx0g04Qzeq2rr46sCk',
#    'genres': ['vlaamse cabaret'],
#    'popularity': 18,
#    'start': 1649371500000,
#    'end': 1649462400000,
#    'stage': 'Loco Royale'}],
#  'Luxor': [{'artist': 'KUZKO',
#    'artist_id': '1XwtSHxSZ06XfQ0qah9Rxo',
#    'genres': ['rotterdam indie'],
#    'popularity': 13,
#    'start': 1649349900000,
#    'end': 1649352600000,
#    'stage': 'Luxor'},
#   {'artist': 'Gallus',
#    'artist_id': '3DTAfcWpBw0deOabOAtNVC',
#    'genres': ['glasgow indie', 'scottish indie rock'],
#    'popularity': 18,
#    'start': 1649356200000,
#    'end': 1649359800000,
#    'stage': 'Luxor'},
#   {'artist': 'The Blue Stones',
#    'artist_id': '5VPCIIfZPK8KPsgz4jmOEC',
#    'genres': ['modern alternative rock',
#     'modern blues rock',
#     'modern hard rock',
#     'windsor on indie'],
#    'popularity': 52,
#    'start': 1649363400000,
#    'end': 1649367000000,
#    'stage': 'Luxor'},
#   {'artist': 'Wodan Boys',
#    'artist_id': '0kmKbibEVmQ4luQqUAHDMr',
#    'genres': ['dutch rock'],
#    'popularity': 17,
#    'start': 1649370600000,
#    'end': 1649374200000,
#    'stage': 'Luxor'}],
#  'Phoenix': [{'artist': 'Tabitha',
#    'artist_id': '7iBY1RLWDV5zX9NDNQxurm',
#    'genres': ['dutch pop', 'dutch rap pop'],
#    'popularity': 56,
#    'start': 1649349000000,
#    'end': 1649352600000,
#    'stage': 'Phoenix'},
#   {'artist': 'Triggerfinger',
#    'artist_id': '3UhIlk54Oe4ja06V962ptU',
#    'genres': ['belgian rock'],
#    'popularity': 39,
#    'start': 1649356200000,
#    'end': 1649359800000,
#    'stage': 'Phoenix'},
#   {'artist': 'Frank Carter & The Rattlesnakes',
#    'artist_id': '3r32a6mMdoPaSP1C7kYhMc',
#    'genres': ['british alternative rock', 'modern alternative rock'],
#    'popularity': 47,
#    'start': 1649363400000,
#    'end': 1649367000000,
#    'stage': 'Phoenix'},
#   {'artist': 'Pan-Pot',
#    'artist_id': '6OQOvP7RAdmAKVXXQqD0Se',
#    'genres': ['german techno', 'minimal techno', 'raw techno'],
#    'popularity': 39,
#    'start': 1649368800000,
#    'end': 1649374200000,
#    'stage': 'Phoenix'},
#   {'artist': 'Enrico Sangiuliano',
#    'artist_id': '1u7DsNFbakULvxnDGtMm90',
#    'genres': ['dark techno', 'italian techno'],
#    'popularity': 55,
#    'start': 1649374200000,
#    'end': 1649466000000,
#    'stage': 'Phoenix'}],
#  'Roxy': [{'artist': 'Go_A',
#    'artist_id': '4kvCU3MzggM2piZCqvxj0x',
#    'genres': ['ukrainian viral pop'],
#    'popularity': 48,
#    'start': 1649289600000,
#    'end': 1649293200000,
#    'stage': 'Roxy'},
#   {'artist': 'Brunzyn',
#    'artist_id': '34zjBncq7MEAoNwsM1DMU9',
#    'genres': [],
#    'popularity': 35,
#    'start': 1649349900000,
#    'end': 1649351700000,
#    'stage': 'Roxy'},
#   {'artist': 'Cor',
#    'artist_id': '66wqVYADY665LeMxs8nlk3',
#    'genres': ['dutch hip hop'],
#    'popularity': 47,
#    'start': 1649353500000,
#    'end': 1649355300000,
#    'stage': 'Roxy'},
#   {'artist': 'Bente',
#    'artist_id': '4U9nsRTH2mr9L4UXEWqG5e',
#    'genres': ['dutch pop'],
#    'popularity': 42,
#    'start': 1649360700000,
#    'end': 1649363400000,
#    'stage': 'Roxy'},
#   {'artist': 'Dopebwoy',
#    'artist_id': '6OQggpm01CmAB717TKtDCr',
#    'genres': ['dutch hip hop', 'dutch rap pop'],
#    'popularity': 58,
#    'start': 1649365200000,
#    'end': 1649367900000,
#    'stage': 'Roxy'},
#   {'artist': 'Rotjoch',
#    'artist_id': '52kkq3LdnSafdKRWjNqKBw',
#    'genres': ['dutch hip hop', 'dutch rap pop'],
#    'popularity': 40,
#    'start': 1649370600000,
#    'end': 1649373300000,
#    'stage': 'Roxy'}],
#  'SMÈRRIG': [{'artist': 'Moschino',
#    'artist_id': '35izkOT62LTsw9eNF2UFbU',
#    'genres': [],
#    'popularity': 0,
#    'start': 1649289600000,
#    'end': 1649293200000,
#    'stage': 'SMÈRRIG'},
#   {'artist': 'Kruzo',
#    'artist_id': '0anbJdkjXYmreS2hXmisVG',
#    'genres': [],
#    'popularity': 31,
#    'start': 1649361600000,
#    'end': 1649365200000,
#    'stage': 'SMÈRRIG'},
#   {'artist': "Be Charm'D",
#    'artist_id': '3CW84Jm2B965uDAskggKF2',
#    'genres': [],
#    'popularity': 1,
#    'start': 1649365200000,
#    'end': 1649368800000,
#    'stage': 'SMÈRRIG'},
#   {'artist': 'Golddiggers',
#    'artist_id': '5XOZGfeMFqgizyqfaUt4t1',
#    'genres': [],
#    'popularity': 20,
#    'start': 1649368800000,
#    'end': 1649372400000,
#    'stage': 'SMÈRRIG'},
#   {'artist': 'Rugged',
#    'artist_id': '3RdyI4MkYrf0VE4suJyMDv',
#    'genres': [],
#    'popularity': 1,
#    'start': 1649372400000,
#    'end': 1649462400000,
#    'stage': 'SMÈRRIG'}],
#  'The Garage': [{'artist': 'The Groove Supplier',
#    'artist_id': '2DFdxWIx41TkkNuFIjhVbE',
#    'genres': [],
#    'popularity': 15,
#    'start': 1649347200000,
#    'end': 1649354400000,
#    'stage': 'The Garage'},
#   {'artist': 'CAJA',
#    'artist_id': '5ay5Vawcw37jUqERz1AyAr',
#    'genres': [],
#    'popularity': 5,
#    'start': 1649354400000,
#    'end': 1649358000000,
#    'stage': 'The Garage'},
#   {'artist': 'Ome Kev',
#    'artist_id': '1esYIpXQ7gz698ru1nMZrD',
#    'genres': [],
#    'popularity': 0,
#    'start': 1649358000000,
#    'end': 1649361600000,
#    'stage': 'The Garage'},
#   {'artist': 'Groove Safari',
#    'artist_id': '1jnLp3FtI86FT8ND2vnncD',
#    'genres': [],
#    'popularity': 1,
#    'start': 1649367000000,
#    'end': 1649372400000,
#    'stage': 'The Garage'}],
#  'The Jack': [{'artist': 'Wargasm',
#    'artist_id': '4heY3O8p8CQHH81wINvExe',
#    'genres': ['boston metal', 'new england metal', 'old school thrash'],
#    'popularity': 8,
#    'start': 1649347200000,
#    'end': 1649350800000,
#    'stage': 'The Jack'},
#   {'artist': 'Ploegendienst',
#    'artist_id': '2aJUvAtem0t0zRKxJsRoea',
#    'genres': ['dutch indie rock', 'dutch punk'],
#    'popularity': 24,
#    'start': 1649354400000,
#    'end': 1649358000000,
#    'stage': 'The Jack'},
#   {'artist': 'Bob Vylan',
#    'artist_id': '6XgIk9Y6qy6JCMZVime6DQ',
#    'genres': ['black punk', 'crank wave'],
#    'popularity': 42,
#    'start': 1649361600000,
#    'end': 1649365200000,
#    'stage': 'The Jack'}],
#  'The Little Theatre': [{'artist': 'Braboneger',
#    'artist_id': '0eK5mdmnyNtFLFQpeIcNqt',
#    'genres': [],
#    'popularity': 0,
#    'start': 1649353500000,
#    'end': 1649355300000,
#    'stage': 'The Little Theatre'},
#   {'artist': 'Braboneger',
#    'artist_id': '0eK5mdmnyNtFLFQpeIcNqt',
#    'genres': [],
#    'popularity': 0,
#    'start': 1649359800000,
#    'end': 1649361600000,
#    'stage': 'The Little Theatre'},
#   {'artist': 'Bingo',
#    'artist_id': '2ESUPsTVS3ffYKFCSIg9FG',
#    'genres': [],
#    'popularity': 7,
#    'start': 1649367900000,
#    'end': 1649462400000,
#    'stage': 'The Little Theatre'}],
#  'The Social club': [{'artist': 'Callkoen',
#    'artist_id': '2SZG72psx2dn8aDVJthfqs',
#    'genres': [],
#    'popularity': 2,
#    'start': 1649347200000,
#    'end': 1649349900000,
#    'stage': 'The Social club'},
#   {'artist': 'Papaformigas',
#    'artist_id': '5OFwcFh2YpR74aHjqY1NuZ',
#    'genres': [],
#    'popularity': 1,
#    'start': 1649352600000,
#    'end': 1649356200000,
#    'stage': 'The Social club'},
#   {'artist': 'The Wetnecks',
#    'artist_id': '0cyyFMYGp2G9TcVbuXYRDu',
#    'genres': [],
#    'popularity': 3,
#    'start': 1649375100000,
#    'end': 1649466000000,
#    'stage': 'The Social club'}],
#  'The sIlver Warehouse': [{'artist': 'Sefa',
#    'artist_id': '0caJEGgVuXuSHhhrMCmlkI',
#    'genres': ['frenchcore', 'tekk', 'uptempo hardcore'],
#    'popularity': 57,
#    'start': 1649289600000,
#    'end': 1649293200000,
#    'stage': 'The sIlver Warehouse'},
#   {'artist': 'La June',
#    'artist_id': '3hHBl5FjVlul5vOJ8cj72f',
#    'genres': [],
#    'popularity': 25,
#    'start': 1649347200000,
#    'end': 1649350800000,
#    'stage': 'The sIlver Warehouse'},
#   {'artist': 'Irwan',
#    'artist_id': '4UP8dCKmHZjqM4DdCqQ5H7',
#    'genres': [],
#    'popularity': 3,
#    'start': 1649350800000,
#    'end': 1649354400000,
#    'stage': 'The sIlver Warehouse'},
#   {'artist': 'Mr. Belt & Wezol',
#    'artist_id': '19VDJ9IKyBSUMDJxLsasP6',
#    'genres': ['dutch edm', 'house'],
#    'popularity': 48,
#    'start': 1649358000000,
#    'end': 1649361600000,
#    'stage': 'The sIlver Warehouse'},
#   {'artist': 'La Fuente',
#    'artist_id': '0vhJymgsCubfAfFjEGVsoD',
#    'genres': ['dutch edm', 'dutch house'],
#    'popularity': 45,
#    'start': 1649361600000,
#    'end': 1649365200000,
#    'stage': 'The sIlver Warehouse'},
#   {'artist': 'Kris Kross Amsterdam',
#    'artist_id': '4LcUpNlXFEleaLlelmkv2R',
#    'genres': ['dutch house', 'dutch pop'],
#    'popularity': 62,
#    'start': 1649365200000,
#    'end': 1649368800000,
#    'stage': 'The sIlver Warehouse'},
#   {'artist': 'Adaro',
#    'artist_id': '05ndiewdJogtosuRWN8iwF',
#    'genres': ['classic hardstyle', 'euphoric hardstyle', 'rawstyle'],
#    'popularity': 46,
#    'start': 1649368800000,
#    'end': 1649372400000,
#    'stage': 'The sIlver Warehouse'},
#   {'artist': 'Vertile',
#    'artist_id': '2CREMC4YATn7Bx9ZQku6IH',
#    'genres': ['rawstyle'],
#    'popularity': 53,
#    'start': 1649372400000,
#    'end': 1649462400000,
#    'stage': 'The sIlver Warehouse'}],
#  'Theatre': [{'artist': 'Martijn Fischer',
#    'artist_id': '3XcxxF0DcHXaSKutfg7vng',
#    'genres': [],
#    'popularity': 10,
#    'start': 1649367000000,
#    'end': 1649372400000,
#    'stage': 'Theatre'},
#   {'artist': 'Baby Blue',
#    'artist_id': '1zG1DuedWyFm98fa1iSoJX',
#    'genres': [],
#    'popularity': 31,
#    'start': 1649374200000,
#    'end': 1649466000000,
#    'stage': 'Theatre'}]}

# %%
list(dater.to_dict('index').values())
# Out:
# [{'artist': 'Martijn Fischer',
#   'artist_id': '3XcxxF0DcHXaSKutfg7vng',
#   'genres': [],
#   'popularity': 10,
#   'start': 1649367000000,
#   'end': 1649372400000,
#   'stage': 'Theatre'},
#  {'artist': 'Baby Blue',
#   'artist_id': '1zG1DuedWyFm98fa1iSoJX',
#   'genres': [],
#   'popularity': 31,
#   'start': 1649374200000,
#   'end': 1649466000000,
#   'stage': 'Theatre'}]

# %%
timetable_dict
# Out:
# {'Apollo': [{'artist': 'MEAU',
#    'artist_id': '2F3Mdh2idBVOiMTxXoxc10',
#    'genres': ['dutch pop'],
#    'popularity': 55,
#    'start': 1649347200000,
#    'end': 1649349900000,
#    'stage': 'Apollo'},
#   {'artist': 'Flemming',
#    'artist_id': '2M8xumdC8KOtdVgjumHYR7',
#    'genres': [],
#    'popularity': 3,
#    'start': 1649352600000,
#    'end': 1649356200000,
#    'stage': 'Apollo'},
#   {'artist': 'Antoon',
#    'artist_id': '5sBoNBXFMzoZjgHLbQueeG',
#    'genres': ['lustrum'],
#    'popularity': 58,
#    'start': 1649359800000,
#    'end': 1649363400000,
#    'stage': 'Apollo'},
#   {'artist': 'DI-RECT',
#    'artist_id': '0d1nFNO90pwRmCeeqjOx2Q',
#    'genres': ['dutch pop', 'dutch rock'],
#    'popularity': 52,
#    'start': 1649367000000,
#    'end': 1649370600000,
#    'stage': 'Apollo'},
#   {'artist': 'Limp Bizkit',
#    'artist_id': '165ZgPlLkK7bf5bDoFc6Sb',
#    'genres': ['alternative metal',
#     'funk metal',
#     'nu metal',
#     'post-grunge',
#     'rap metal',
#     'rock'],
#    'popularity': 74,
#    'start': 1649374200000,
#    'end': 1649466000000,
#    'stage': 'Apollo'}],
#  'Area 9': [{'artist': 'The Juke Joints',
#    'artist_id': '3B8uylp9cvNkcg8XOSZ3c9',
#    'genres': ['dutch blues'],
#    'popularity': 8,
#    'start': 1649356200000,
#    'end': 1649359800000,
#    'stage': 'Area 9'},
#   {'artist': 'Piledriver',
#    'artist_id': '4IkzquGzaHJr0O4snJAoSb',
#    'genres': ['old school thrash'],
#    'popularity': 11,
#    'start': 1649374200000,
#    'end': 1649464200000,
#    'stage': 'Area 9'}],
#  'Casa Barcardi': [{'artist': 'Jorda',
#    'artist_id': '2JFrOlm8n2quN9uQ2lkeO5',
#    'genres': [],
#    'popularity': 28,
#    'start': 1649289600000,
#    'end': 1649293200000,
#    'stage': 'Casa Barcardi'},
#   {'artist': 'Morry',
#    'artist_id': '1CXa8YMTen75u0n1rvtk0u',
#    'genres': [],
#    'popularity': 27,
#    'start': 1649349000000,
#    'end': 1649355300000,
#    'stage': 'Casa Barcardi'},
#   {'artist': 'Nereo',
#    'artist_id': '5bO4qIfLbIYaI685z1tGoi',
#    'genres': [],
#    'popularity': 0,
#    'start': 1649355300000,
#    'end': 1649356200000,
#    'stage': 'Casa Barcardi'},
#   {'artist': 'Elin Valery',
#    'artist_id': '45z8eLb85OUwgx6LNZZaAK',
#    'genres': [],
#    'popularity': 0,
#    'start': 1649358000000,
#    'end': 1649362500000,
#    'stage': 'Casa Barcardi'},
#   {'artist': 'Jorda',
#    'artist_id': '2JFrOlm8n2quN9uQ2lkeO5',
#    'genres': [],
#    'popularity': 28,
#    'start': 1649362500000,
#    'end': 1649365800000,
#    'stage': 'Casa Barcardi'},
#   {'artist': 'Morry',
#    'artist_id': '1CXa8YMTen75u0n1rvtk0u',
#    'genres': [],
#    'popularity': 27,
#    'start': 1649367000000,
#    'end': 1649372400000,
#    'stage': 'Casa Barcardi'},
#   {'artist': 'MIMI',
#    'artist_id': '0nwGsQzwVqdlBAg0eSNxmd',
#    'genres': ['vocaloid'],
#    'popularity': 49,
#    'start': 1649372400000,
#    'end': 1649462400000,
#    'stage': 'Casa Barcardi'}],
#  'Disco Snolly': [{'artist': 'De Manager',
#    'artist_id': '6VTHagpigZbq1jEgAXtlmE',
#    'genres': [],
#    'popularity': 0,
#    'start': 1649349000000,
#    'end': 1649354400000,
#    'stage': 'Disco Snolly'},
#   {'artist': 'Disco Snolly',
#    'artist_id': '2E5q3OwDr5WR0Bfcwpunhb',
#    'genres': [],
#    'popularity': 16,
#    'start': 1649374200000,
#    'end': 1649466000000,
#    'stage': 'Disco Snolly'}],
#  'Dolle Mina': [{'artist': 'Arjon Oostrom',
#    'artist_id': '2sdP2pb74y3kf44RxZwaCb',
#    'genres': ['carnaval', 'levenslied'],
#    'popularity': 41,
#    'start': 1649289600000,
#    'end': 1649291400000,
#    'stage': 'Dolle Mina'},
#   {'artist': 'Dirk Drost',
#    'artist_id': '3nK6TYPkGYtOVooSX52j7A',
#    'genres': [],
#    'popularity': 0,
#    'start': 1649350800000,
#    'end': 1649352600000,
#    'stage': 'Dolle Mina'},
#   {'artist': 'René Ulehake',
#    'artist_id': '0PCA8sf9m99GF1nxZYq2me',
#    'genres': [],
#    'popularity': 0,
#    'start': 1649356200000,
#    'end': 1649358000000,
#    'stage': 'Dolle Mina'},
#   {'artist': 'Marco Kanters',
#    'artist_id': '2VF4qPKEmzjjssI2razMNt',
#    'genres': ['carnaval', 'levenslied'],
#    'popularity': 36,
#    'start': 1649363400000,
#    'end': 1649365200000,
#    'stage': 'Dolle Mina'}],
#  'Loco Royale': [{'artist': 'Show',
#    'artist_id': '2lXKd25ihVzaQf7rDaijUh',
#    'genres': [],
#    'popularity': 5,
#    'start': 1649355300000,
#    'end': 1649358900000,
#    'stage': 'Loco Royale'},
#   {'artist': 'Pure Ellende',
#    'artist_id': '63czbS5lyZfjE3M8b0bPdX',
#    'genres': [],
#    'popularity': 0,
#    'start': 1649360700000,
#    'end': 1649364300000,
#    'stage': 'Loco Royale'},
#   {'artist': 'STUK',
#    'artist_id': '0MnM8NE69iw1cVc7GVIZ41',
#    'genres': ['nederlandse hardstyle'],
#    'popularity': 36,
#    'start': 1649366100000,
#    'end': 1649369700000,
#    'stage': 'Loco Royale'},
#   {'artist': 'Gestapo Knallmuzik',
#    'artist_id': '1nqxhx0g04Qzeq2rr46sCk',
#    'genres': ['vlaamse cabaret'],
#    'popularity': 18,
#    'start': 1649371500000,
#    'end': 1649462400000,
#    'stage': 'Loco Royale'}],
#  'Luxor': [{'artist': 'KUZKO',
#    'artist_id': '1XwtSHxSZ06XfQ0qah9Rxo',
#    'genres': ['rotterdam indie'],
#    'popularity': 13,
#    'start': 1649349900000,
#    'end': 1649352600000,
#    'stage': 'Luxor'},
#   {'artist': 'Gallus',
#    'artist_id': '3DTAfcWpBw0deOabOAtNVC',
#    'genres': ['glasgow indie', 'scottish indie rock'],
#    'popularity': 18,
#    'start': 1649356200000,
#    'end': 1649359800000,
#    'stage': 'Luxor'},
#   {'artist': 'The Blue Stones',
#    'artist_id': '5VPCIIfZPK8KPsgz4jmOEC',
#    'genres': ['modern alternative rock',
#     'modern blues rock',
#     'modern hard rock',
#     'windsor on indie'],
#    'popularity': 52,
#    'start': 1649363400000,
#    'end': 1649367000000,
#    'stage': 'Luxor'},
#   {'artist': 'Wodan Boys',
#    'artist_id': '0kmKbibEVmQ4luQqUAHDMr',
#    'genres': ['dutch rock'],
#    'popularity': 17,
#    'start': 1649370600000,
#    'end': 1649374200000,
#    'stage': 'Luxor'}],
#  'Phoenix': [{'artist': 'Tabitha',
#    'artist_id': '7iBY1RLWDV5zX9NDNQxurm',
#    'genres': ['dutch pop', 'dutch rap pop'],
#    'popularity': 56,
#    'start': 1649349000000,
#    'end': 1649352600000,
#    'stage': 'Phoenix'},
#   {'artist': 'Triggerfinger',
#    'artist_id': '3UhIlk54Oe4ja06V962ptU',
#    'genres': ['belgian rock'],
#    'popularity': 39,
#    'start': 1649356200000,
#    'end': 1649359800000,
#    'stage': 'Phoenix'},
#   {'artist': 'Frank Carter & The Rattlesnakes',
#    'artist_id': '3r32a6mMdoPaSP1C7kYhMc',
#    'genres': ['british alternative rock', 'modern alternative rock'],
#    'popularity': 47,
#    'start': 1649363400000,
#    'end': 1649367000000,
#    'stage': 'Phoenix'},
#   {'artist': 'Pan-Pot',
#    'artist_id': '6OQOvP7RAdmAKVXXQqD0Se',
#    'genres': ['german techno', 'minimal techno', 'raw techno'],
#    'popularity': 39,
#    'start': 1649368800000,
#    'end': 1649374200000,
#    'stage': 'Phoenix'},
#   {'artist': 'Enrico Sangiuliano',
#    'artist_id': '1u7DsNFbakULvxnDGtMm90',
#    'genres': ['dark techno', 'italian techno'],
#    'popularity': 55,
#    'start': 1649374200000,
#    'end': 1649466000000,
#    'stage': 'Phoenix'}],
#  'Roxy': [{'artist': 'Go_A',
#    'artist_id': '4kvCU3MzggM2piZCqvxj0x',
#    'genres': ['ukrainian viral pop'],
#    'popularity': 48,
#    'start': 1649289600000,
#    'end': 1649293200000,
#    'stage': 'Roxy'},
#   {'artist': 'Brunzyn',
#    'artist_id': '34zjBncq7MEAoNwsM1DMU9',
#    'genres': [],
#    'popularity': 35,
#    'start': 1649349900000,
#    'end': 1649351700000,
#    'stage': 'Roxy'},
#   {'artist': 'Cor',
#    'artist_id': '66wqVYADY665LeMxs8nlk3',
#    'genres': ['dutch hip hop'],
#    'popularity': 47,
#    'start': 1649353500000,
#    'end': 1649355300000,
#    'stage': 'Roxy'},
#   {'artist': 'Bente',
#    'artist_id': '4U9nsRTH2mr9L4UXEWqG5e',
#    'genres': ['dutch pop'],
#    'popularity': 42,
#    'start': 1649360700000,
#    'end': 1649363400000,
#    'stage': 'Roxy'},
#   {'artist': 'Dopebwoy',
#    'artist_id': '6OQggpm01CmAB717TKtDCr',
#    'genres': ['dutch hip hop', 'dutch rap pop'],
#    'popularity': 58,
#    'start': 1649365200000,
#    'end': 1649367900000,
#    'stage': 'Roxy'},
#   {'artist': 'Rotjoch',
#    'artist_id': '52kkq3LdnSafdKRWjNqKBw',
#    'genres': ['dutch hip hop', 'dutch rap pop'],
#    'popularity': 40,
#    'start': 1649370600000,
#    'end': 1649373300000,
#    'stage': 'Roxy'}],
#  'SMÈRRIG': [{'artist': 'Moschino',
#    'artist_id': '35izkOT62LTsw9eNF2UFbU',
#    'genres': [],
#    'popularity': 0,
#    'start': 1649289600000,
#    'end': 1649293200000,
#    'stage': 'SMÈRRIG'},
#   {'artist': 'Kruzo',
#    'artist_id': '0anbJdkjXYmreS2hXmisVG',
#    'genres': [],
#    'popularity': 31,
#    'start': 1649361600000,
#    'end': 1649365200000,
#    'stage': 'SMÈRRIG'},
#   {'artist': "Be Charm'D",
#    'artist_id': '3CW84Jm2B965uDAskggKF2',
#    'genres': [],
#    'popularity': 1,
#    'start': 1649365200000,
#    'end': 1649368800000,
#    'stage': 'SMÈRRIG'},
#   {'artist': 'Golddiggers',
#    'artist_id': '5XOZGfeMFqgizyqfaUt4t1',
#    'genres': [],
#    'popularity': 20,
#    'start': 1649368800000,
#    'end': 1649372400000,
#    'stage': 'SMÈRRIG'},
#   {'artist': 'Rugged',
#    'artist_id': '3RdyI4MkYrf0VE4suJyMDv',
#    'genres': [],
#    'popularity': 1,
#    'start': 1649372400000,
#    'end': 1649462400000,
#    'stage': 'SMÈRRIG'}],
#  'The Garage': [{'artist': 'The Groove Supplier',
#    'artist_id': '2DFdxWIx41TkkNuFIjhVbE',
#    'genres': [],
#    'popularity': 15,
#    'start': 1649347200000,
#    'end': 1649354400000,
#    'stage': 'The Garage'},
#   {'artist': 'CAJA',
#    'artist_id': '5ay5Vawcw37jUqERz1AyAr',
#    'genres': [],
#    'popularity': 5,
#    'start': 1649354400000,
#    'end': 1649358000000,
#    'stage': 'The Garage'},
#   {'artist': 'Ome Kev',
#    'artist_id': '1esYIpXQ7gz698ru1nMZrD',
#    'genres': [],
#    'popularity': 0,
#    'start': 1649358000000,
#    'end': 1649361600000,
#    'stage': 'The Garage'},
#   {'artist': 'Groove Safari',
#    'artist_id': '1jnLp3FtI86FT8ND2vnncD',
#    'genres': [],
#    'popularity': 1,
#    'start': 1649367000000,
#    'end': 1649372400000,
#    'stage': 'The Garage'}],
#  'The Jack': [{'artist': 'Wargasm',
#    'artist_id': '4heY3O8p8CQHH81wINvExe',
#    'genres': ['boston metal', 'new england metal', 'old school thrash'],
#    'popularity': 8,
#    'start': 1649347200000,
#    'end': 1649350800000,
#    'stage': 'The Jack'},
#   {'artist': 'Ploegendienst',
#    'artist_id': '2aJUvAtem0t0zRKxJsRoea',
#    'genres': ['dutch indie rock', 'dutch punk'],
#    'popularity': 24,
#    'start': 1649354400000,
#    'end': 1649358000000,
#    'stage': 'The Jack'},
#   {'artist': 'Bob Vylan',
#    'artist_id': '6XgIk9Y6qy6JCMZVime6DQ',
#    'genres': ['black punk', 'crank wave'],
#    'popularity': 42,
#    'start': 1649361600000,
#    'end': 1649365200000,
#    'stage': 'The Jack'}],
#  'The Little Theatre': [{'artist': 'Braboneger',
#    'artist_id': '0eK5mdmnyNtFLFQpeIcNqt',
#    'genres': [],
#    'popularity': 0,
#    'start': 1649353500000,
#    'end': 1649355300000,
#    'stage': 'The Little Theatre'},
#   {'artist': 'Braboneger',
#    'artist_id': '0eK5mdmnyNtFLFQpeIcNqt',
#    'genres': [],
#    'popularity': 0,
#    'start': 1649359800000,
#    'end': 1649361600000,
#    'stage': 'The Little Theatre'},
#   {'artist': 'Bingo',
#    'artist_id': '2ESUPsTVS3ffYKFCSIg9FG',
#    'genres': [],
#    'popularity': 7,
#    'start': 1649367900000,
#    'end': 1649462400000,
#    'stage': 'The Little Theatre'}],
#  'The Social club': [{'artist': 'Callkoen',
#    'artist_id': '2SZG72psx2dn8aDVJthfqs',
#    'genres': [],
#    'popularity': 2,
#    'start': 1649347200000,
#    'end': 1649349900000,
#    'stage': 'The Social club'},
#   {'artist': 'Papaformigas',
#    'artist_id': '5OFwcFh2YpR74aHjqY1NuZ',
#    'genres': [],
#    'popularity': 1,
#    'start': 1649352600000,
#    'end': 1649356200000,
#    'stage': 'The Social club'},
#   {'artist': 'The Wetnecks',
#    'artist_id': '0cyyFMYGp2G9TcVbuXYRDu',
#    'genres': [],
#    'popularity': 3,
#    'start': 1649375100000,
#    'end': 1649466000000,
#    'stage': 'The Social club'}],
#  'The sIlver Warehouse': [{'artist': 'Sefa',
#    'artist_id': '0caJEGgVuXuSHhhrMCmlkI',
#    'genres': ['frenchcore', 'tekk', 'uptempo hardcore'],
#    'popularity': 57,
#    'start': 1649289600000,
#    'end': 1649293200000,
#    'stage': 'The sIlver Warehouse'},
#   {'artist': 'La June',
#    'artist_id': '3hHBl5FjVlul5vOJ8cj72f',
#    'genres': [],
#    'popularity': 25,
#    'start': 1649347200000,
#    'end': 1649350800000,
#    'stage': 'The sIlver Warehouse'},
#   {'artist': 'Irwan',
#    'artist_id': '4UP8dCKmHZjqM4DdCqQ5H7',
#    'genres': [],
#    'popularity': 3,
#    'start': 1649350800000,
#    'end': 1649354400000,
#    'stage': 'The sIlver Warehouse'},
#   {'artist': 'Mr. Belt & Wezol',
#    'artist_id': '19VDJ9IKyBSUMDJxLsasP6',
#    'genres': ['dutch edm', 'house'],
#    'popularity': 48,
#    'start': 1649358000000,
#    'end': 1649361600000,
#    'stage': 'The sIlver Warehouse'},
#   {'artist': 'La Fuente',
#    'artist_id': '0vhJymgsCubfAfFjEGVsoD',
#    'genres': ['dutch edm', 'dutch house'],
#    'popularity': 45,
#    'start': 1649361600000,
#    'end': 1649365200000,
#    'stage': 'The sIlver Warehouse'},
#   {'artist': 'Kris Kross Amsterdam',
#    'artist_id': '4LcUpNlXFEleaLlelmkv2R',
#    'genres': ['dutch house', 'dutch pop'],
#    'popularity': 62,
#    'start': 1649365200000,
#    'end': 1649368800000,
#    'stage': 'The sIlver Warehouse'},
#   {'artist': 'Adaro',
#    'artist_id': '05ndiewdJogtosuRWN8iwF',
#    'genres': ['classic hardstyle', 'euphoric hardstyle', 'rawstyle'],
#    'popularity': 46,
#    'start': 1649368800000,
#    'end': 1649372400000,
#    'stage': 'The sIlver Warehouse'},
#   {'artist': 'Vertile',
#    'artist_id': '2CREMC4YATn7Bx9ZQku6IH',
#    'genres': ['rawstyle'],
#    'popularity': 53,
#    'start': 1649372400000,
#    'end': 1649462400000,
#    'stage': 'The sIlver Warehouse'}],
#  'Theatre': [{'artist': 'Martijn Fischer',
#    'artist_id': '3XcxxF0DcHXaSKutfg7vng',
#    'genres': [],
#    'popularity': 10,
#    'start': 1649367000000,
#    'end': 1649372400000,
#    'stage': 'Theatre'},
#   {'artist': 'Baby Blue',
#    'artist_id': '1zG1DuedWyFm98fa1iSoJX',
#    'genres': [],
#    'popularity': 31,
#    'start': 1649374200000,
#    'end': 1649466000000,
#    'stage': 'Theatre'}]}

# %%
timetable_df.merge()
# Out:
#                   artist               artist_id  \
# 0                   MEAU  2F3Mdh2idBVOiMTxXoxc10
# 1               Flemming  2M8xumdC8KOtdVgjumHYR7
# 2                 Antoon  5sBoNBXFMzoZjgHLbQueeG
# 3                DI-RECT  0d1nFNO90pwRmCeeqjOx2Q
# 4            Limp Bizkit  165ZgPlLkK7bf5bDoFc6Sb
# ..                   ...                     ...
# 5   Kris Kross Amsterdam  4LcUpNlXFEleaLlelmkv2R
# 6                  Adaro  05ndiewdJogtosuRWN8iwF
# 7                Vertile  2CREMC4YATn7Bx9ZQku6IH
# 0        Martijn Fischer  3XcxxF0DcHXaSKutfg7vng
# 1              Baby Blue  1zG1DuedWyFm98fa1iSoJX
#
#                                                genres  popularity  \
# 0                                         [dutch pop]          55
# 1                                                  []           3
# 2                                           [lustrum]          58
# 3                             [dutch pop, dutch rock]          52
# 4   [alternative metal, funk metal, nu metal, post...          74
# ..                                                ...         ...
# 5                            [dutch house, dutch pop]          62
# 6   [classic hardstyle, euphoric hardstyle, rawstyle]          46
# 7                                          [rawstyle]          53
# 0                                                  []          10
# 1                                                  []          31
#
#             start            end                 stage
# 0   1649347200000  1649349900000                Apollo
# 1   1649352600000  1649356200000                Apollo
# 2   1649359800000  1649363400000                Apollo
# 3   1649367000000  1649370600000                Apollo
# 4   1649374200000  1649466000000                Apollo
# ..            ...            ...                   ...
# 5   1649365200000  1649368800000  The sIlver Warehouse
# 6   1649368800000  1649372400000  The sIlver Warehouse
# 7   1649372400000  1649462400000  The sIlver Warehouse
# 0   1649367000000  1649372400000               Theatre
# 1   1649374200000  1649466000000               Theatre
#
# [67 rows x 7 columns]

# %%
with open("Sheet.pkl", "rb") as f:
    df = pd.read_pickle(f)

# %%
df
# Out:
#                    stage                           artist          start  \
# 0                 Apollo                           Antoon  1649359800000
# 1                 Apollo                          DI-RECT  1649367000000
# 2                 Apollo                      Limp Bizkit  1649374200000
# 3          Casa Barcardi                            Jorda  1649289600000
# 4          Casa Barcardi                            K-man  1649343600000
# 5          Casa Barcardi                            Jorda  1649362500000
# 6          Casa Barcardi                     Kilate Tesla  1649365800000
# 7             Dolle Mina                    John de Bever  1649369700000
# 8            Loco Royale               Gestapo Knallmuzik  1649371500000
# 9                Phoenix                          Tabitha  1649349000000
# 10               Phoenix                    Triggerfinger  1649356200000
# 11               Phoenix  Frank Carter & The Rattlesnakes  1649363400000
# 12                  Roxy                          Brunzyn  1649349900000
# 13                  Roxy                          Rotjoch  1649370600000
# 14              The Jack                    Ploegendienst  1649354400000
# 15              The Jack                        Bob Vylan  1649361600000
# 16       The Social club                     The Wetnecks  1649375100000
# 17  The sIlver Warehouse                          La June  1649347200000
# 18  The sIlver Warehouse                 Mr. Belt & Wezol  1649358000000
# 19  The sIlver Warehouse             Kris Kross Amsterdam  1649365200000
# 20  The sIlver Warehouse                            Adaro  1649368800000
# 21  The sIlver Warehouse                          Vertile  1649372400000
#
#               end
# 0   1649363400000
# 1   1649370600000
# 2   1649466000000
# 3   1649293200000
# 4   1649349000000
# 5   1649365800000
# 6   1649367000000
# 7   1649371500000
# 8   1649462400000
# 9   1649352600000
# 10  1649359800000
# 11  1649367000000
# 12  1649351700000
# 13  1649373300000
# 14  1649358000000
# 15  1649365200000
# 16  1649466000000
# 17  1649350800000
# 18  1649361600000
# 19  1649368800000
# 20  1649372400000
# 21  1649462400000

# %%
with open("restructured_timetable_paaspop_friday.json", "w") as f:
    data = json.load(f)
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[43], line 2
#       1 with open("restructured_timetable_paaspop_friday.json", "w") as f:
# ----> 2     data = json.load(f)
#
# File C:\Python311\Lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# UnsupportedOperation: not readable

# %%
list(df.to_dict('index').values())
# Out:
# [{'stage': 'Apollo',
#   'artist': 'Antoon',
#   'start': 1649359800000,
#   'end': 1649363400000},
#  {'stage': 'Apollo',
#   'artist': 'DI-RECT',
#   'start': 1649367000000,
#   'end': 1649370600000},
#  {'stage': 'Apollo',
#   'artist': 'Limp Bizkit',
#   'start': 1649374200000,
#   'end': 1649466000000},
#  {'stage': 'Casa Barcardi',
#   'artist': 'Jorda',
#   'start': 1649289600000,
#   'end': 1649293200000},
#  {'stage': 'Casa Barcardi',
#   'artist': 'K-man',
#   'start': 1649343600000,
#   'end': 1649349000000},
#  {'stage': 'Casa Barcardi',
#   'artist': 'Jorda',
#   'start': 1649362500000,
#   'end': 1649365800000},
#  {'stage': 'Casa Barcardi',
#   'artist': 'Kilate Tesla',
#   'start': 1649365800000,
#   'end': 1649367000000},
#  {'stage': 'Dolle Mina',
#   'artist': 'John de Bever',
#   'start': 1649369700000,
#   'end': 1649371500000},
#  {'stage': 'Loco Royale',
#   'artist': 'Gestapo Knallmuzik',
#   'start': 1649371500000,
#   'end': 1649462400000},
#  {'stage': 'Phoenix',
#   'artist': 'Tabitha',
#   'start': 1649349000000,
#   'end': 1649352600000},
#  {'stage': 'Phoenix',
#   'artist': 'Triggerfinger',
#   'start': 1649356200000,
#   'end': 1649359800000},
#  {'stage': 'Phoenix',
#   'artist': 'Frank Carter & The Rattlesnakes',
#   'start': 1649363400000,
#   'end': 1649367000000},
#  {'stage': 'Roxy',
#   'artist': 'Brunzyn',
#   'start': 1649349900000,
#   'end': 1649351700000},
#  {'stage': 'Roxy',
#   'artist': 'Rotjoch',
#   'start': 1649370600000,
#   'end': 1649373300000},
#  {'stage': 'The Jack',
#   'artist': 'Ploegendienst',
#   'start': 1649354400000,
#   'end': 1649358000000},
#  {'stage': 'The Jack',
#   'artist': 'Bob Vylan',
#   'start': 1649361600000,
#   'end': 1649365200000},
#  {'stage': 'The Social club',
#   'artist': 'The Wetnecks',
#   'start': 1649375100000,
#   'end': 1649466000000},
#  {'stage': 'The sIlver Warehouse',
#   'artist': 'La June',
#   'start': 1649347200000,
#   'end': 1649350800000},
#  {'stage': 'The sIlver Warehouse',
#   'artist': 'Mr. Belt & Wezol',
#   'start': 1649358000000,
#   'end': 1649361600000},
#  {'stage': 'The sIlver Warehouse',
#   'artist': 'Kris Kross Amsterdam',
#   'start': 1649365200000,
#   'end': 1649368800000},
#  {'stage': 'The sIlver Warehouse',
#   'artist': 'Adaro',
#   'start': 1649368800000,
#   'end': 1649372400000},
#  {'stage': 'The sIlver Warehouse',
#   'artist': 'Vertile',
#   'start': 1649372400000,
#   'end': 1649462400000}]

# %%
artist_id_list = []
for key, value in timetable_dict.items():
    for entry in value:
        artist_id_list.append(entry["artist_id"])

# %%
artist_id_list
# Out:
# ['2F3Mdh2idBVOiMTxXoxc10',
#  '2M8xumdC8KOtdVgjumHYR7',
#  '5sBoNBXFMzoZjgHLbQueeG',
#  '0d1nFNO90pwRmCeeqjOx2Q',
#  '165ZgPlLkK7bf5bDoFc6Sb',
#  '3B8uylp9cvNkcg8XOSZ3c9',
#  '4IkzquGzaHJr0O4snJAoSb',
#  '2JFrOlm8n2quN9uQ2lkeO5',
#  '1CXa8YMTen75u0n1rvtk0u',
#  '5bO4qIfLbIYaI685z1tGoi',
#  '45z8eLb85OUwgx6LNZZaAK',
#  '2JFrOlm8n2quN9uQ2lkeO5',
#  '1CXa8YMTen75u0n1rvtk0u',
#  '0nwGsQzwVqdlBAg0eSNxmd',
#  '6VTHagpigZbq1jEgAXtlmE',
#  '2E5q3OwDr5WR0Bfcwpunhb',
#  '2sdP2pb74y3kf44RxZwaCb',
#  '3nK6TYPkGYtOVooSX52j7A',
#  '0PCA8sf9m99GF1nxZYq2me',
#  '2VF4qPKEmzjjssI2razMNt',
#  '2lXKd25ihVzaQf7rDaijUh',
#  '63czbS5lyZfjE3M8b0bPdX',
#  '0MnM8NE69iw1cVc7GVIZ41',
#  '1nqxhx0g04Qzeq2rr46sCk',
#  '1XwtSHxSZ06XfQ0qah9Rxo',
#  '3DTAfcWpBw0deOabOAtNVC',
#  '5VPCIIfZPK8KPsgz4jmOEC',
#  '0kmKbibEVmQ4luQqUAHDMr',
#  '7iBY1RLWDV5zX9NDNQxurm',
#  '3UhIlk54Oe4ja06V962ptU',
#  '3r32a6mMdoPaSP1C7kYhMc',
#  '6OQOvP7RAdmAKVXXQqD0Se',
#  '1u7DsNFbakULvxnDGtMm90',
#  '4kvCU3MzggM2piZCqvxj0x',
#  '34zjBncq7MEAoNwsM1DMU9',
#  '66wqVYADY665LeMxs8nlk3',
#  '4U9nsRTH2mr9L4UXEWqG5e',
#  '6OQggpm01CmAB717TKtDCr',
#  '52kkq3LdnSafdKRWjNqKBw',
#  '35izkOT62LTsw9eNF2UFbU',
#  '0anbJdkjXYmreS2hXmisVG',
#  '3CW84Jm2B965uDAskggKF2',
#  '5XOZGfeMFqgizyqfaUt4t1',
#  '3RdyI4MkYrf0VE4suJyMDv',
#  '2DFdxWIx41TkkNuFIjhVbE',
#  '5ay5Vawcw37jUqERz1AyAr',
#  '1esYIpXQ7gz698ru1nMZrD',
#  '1jnLp3FtI86FT8ND2vnncD',
#  '4heY3O8p8CQHH81wINvExe',
#  '2aJUvAtem0t0zRKxJsRoea',
#  '6XgIk9Y6qy6JCMZVime6DQ',
#  '0eK5mdmnyNtFLFQpeIcNqt',
#  '0eK5mdmnyNtFLFQpeIcNqt',
#  '2ESUPsTVS3ffYKFCSIg9FG',
#  '2SZG72psx2dn8aDVJthfqs',
#  '5OFwcFh2YpR74aHjqY1NuZ',
#  '0cyyFMYGp2G9TcVbuXYRDu',
#  '0caJEGgVuXuSHhhrMCmlkI',
#  '3hHBl5FjVlul5vOJ8cj72f',
#  '4UP8dCKmHZjqM4DdCqQ5H7',
#  '19VDJ9IKyBSUMDJxLsasP6',
#  '0vhJymgsCubfAfFjEGVsoD',
#  '4LcUpNlXFEleaLlelmkv2R',
#  '05ndiewdJogtosuRWN8iwF',
#  '2CREMC4YATn7Bx9ZQku6IH',
#  '3XcxxF0DcHXaSKutfg7vng',
#  '1zG1DuedWyFm98fa1iSoJX']
